# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Mar 21 15:47:34 2018

@author: alyshadesouza
"""
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy import stats
from IPython.display import SVG,display

'''
f1 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t1/lamp_means.csv')
f2 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t2/lamp_means.csv')
f3 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t3/lamp_means.csv')
f4 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t4/lamp_means.csv')
f5 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t5/lamp_means.csv')
f6 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t6/lamp_means.csv')
f7 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t7/lamp_means.csv')

f8 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t8/lamp_means.csv')
f9 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t9/lamp_means.csv')
f10 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t10/lamp_means.csv')
f11 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t11/lamp_means.csv')
f12 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t12/lamp_means.csv')
f13 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t13/lamp_means.csv')
f14 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t14/lamp_means.csv')
f15 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t15/lamp_means.csv')
#
f16 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t16/lamp_means.csv')
f17 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t17/lamp_means.csv')
f18 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t18/lamp_means.csv')
f19 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t19/lamp_means.csv')
f20 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t20/lamp_means.csv')
'''
'''
f0 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/0freq_analysis.csv')
f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/1freq_analysis.csv')
f2 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/2freq_analysis.csv')
f3 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/3freq_analysis.csv')
f4 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/4freq_analysis.csv')
f5 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/5freq_analysis.csv')
f6 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/6freq_analysis.csv')
f7 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/7freq_analysis.csv')
f8 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/8freq_analysis.csv')
f9 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/9freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')

f20 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/0freq_analysis.csv')
f21 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/1freq_analysis.csv')
f22 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/2freq_analysis.csv')
f23 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/3freq_analysis.csv')
f24 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/4freq_analysis.csv')
f25 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/5freq_analysis.csv')
f26 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/6freq_analysis.csv')
f27 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/7freq_analysis.csv')
f28 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/8freq_analysis.csv')
f29 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/9freq_analysis.csv')

f40 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/0freq_analysis.csv')
f41 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/1freq_analysis.csv')
f42 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/2freq_analysis.csv')
f43 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/3freq_analysis.csv')
f44 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/4freq_analysis.csv')
f45 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/5freq_analysis.csv')
f46 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/6freq_analysis.csv')
f47 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/7freq_analysis.csv')
f48 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/8freq_analysis.csv')
f49 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/9freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')

f60 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/0freq_analysis.csv')
f61 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/1freq_analysis.csv')
f62 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/2freq_analysis.csv')
f63 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/3freq_analysis.csv')
f64 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/4freq_analysis.csv')
f65 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/5freq_analysis.csv')
f66 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/6freq_analysis.csv')
f67 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/7freq_analysis.csv')
f68 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/8freq_analysis.csv')
f69 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/9freq_analysis.csv')

f80 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/0freq_analysis.csv')
f81 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/1freq_analysis.csv')
f82 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/2freq_analysis.csv')
f83 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/3freq_analysis.csv')
f84 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/4freq_analysis.csv')
f85 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/5freq_analysis.csv')
f86 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/6freq_analysis.csv')
f87 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/7freq_analysis.csv')
f88 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/8freq_analysis.csv')
f89 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/9freq_analysis.csv')
'''
'''
f10 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0WSA_analysis.csv')
f11 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/1WSA_analysis.csv')
f12 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/2WSA_analysis.csv')
f13 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/3WSA_analysis.csv')
f14 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/4WSA_analysis.csv')
f15 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/5WSA_analysis.csv')
f16 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/6WSA_analysis.csv')
f17 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/7WSA_analysis.csv')
f18 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/8WSA_analysis.csv')
f19 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/9WSA_analysis.csv')

'''
'''
f10 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/0WSA_analysis.csv')
f11 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/1WSA_analysis.csv')
f12 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/2WSA_analysis.csv')
f13 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/3WSA_analysis.csv')
f14 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/4WSA_analysis.csv')
f15 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/5WSA_analysis.csv')
f16 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/6WSA_analysis.csv')
f17 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/7WSA_analysis.csv')
f18 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/8WSA_analysis.csv')
f19 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/9WSA_analysis.csv')

'''
'''
f30 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/0WSA_analysis.csv')
f31 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/1WSA_analysis.csv')
f32 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/2WSA_analysis.csv')
f33 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/3WSA_analysis.csv')
f34 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/4WSA_analysis.csv')
f35 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/5WSA_analysis.csv')
f36 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/6WSA_analysis.csv')
f37 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/7WSA_analysis.csv')
f38 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/8WSA_analysis.csv')
f39 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/9WSA_analysis.csv')

f50 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/0WSA_analysis.csv')
f51 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/1WSA_analysis.csv')
f52 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/2WSA_analysis.csv')
f53 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/3WSA_analysis.csv')
f54 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/4WSA_analysis.csv')
f55 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/5WSA_analysis.csv')
f56 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/6WSA_analysis.csv')
f57 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/7WSA_analysis.csv')
f58 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/8WSA_analysis.csv')
f59 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/9WSA_analysis.csv')

f70 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/0WSA_analysis.csv')
f71 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/1WSA_analysis.csv')
f72 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/2WSA_analysis.csv')
f73 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/3WSA_analysis.csv')
f74 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/4WSA_analysis.csv')
f75 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/5WSA_analysis.csv')
f76 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/6WSA_analysis.csv')
f77 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/7WSA_analysis.csv')
f78 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/8WSA_analysis.csv')
f79 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/9WSA_analysis.csv')

f90 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/0WSA_analysis.csv')
f91 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/1WSA_analysis.csv')
f92 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/2WSA_analysis.csv')
f93 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/3WSA_analysis.csv')
f94 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/4WSA_analysis.csv')
f95 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/5WSA_analysis.csv')
f96 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/6WSA_analysis.csv')
f97 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/7WSA_analysis.csv')
f98 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/8WSA_analysis.csv')
f99 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/9WSA_analysis.csv')




'''



f0 = pd.read_csv('/home/alysha/analysis_files/S114/csv/010freq_analysis.csv')
f1 = pd.read_csv('/home/alysha/analysis_files/S114/csv/011freq_analysis.csv')
f2 = pd.read_csv('/home/alysha/analysis_files/S114/csv/012freq_analysis.csv')
f3 = pd.read_csv('/home/alysha/analysis_files/S114/csv/013freq_analysis.csv')
f4 = pd.read_csv('/home/alysha/analysis_files/S114/csv/014freq_analysis.csv')
f5 = pd.read_csv('/home/alysha/analysis_files/S114/csv/015freq_analysis.csv')                 
f6 = pd.read_csv('/home/alysha/analysis_files/S114/csv/016freq_analysis.csv')
f7 = pd.read_csv('/home/alysha/analysis_files/S114/csv/017freq_analysis.csv')
f8 = pd.read_csv('/home/alysha/analysis_files/S114/csv/018freq_analysis.csv')
f9 = pd.read_csv('/home/alysha/analysis_files/S114/csv/019freq_analysis.csv')
#f10 = pd.read_csv('/home/alysha/analysis_files/S114/csv/020freq_analysis.csv')
#f11 = pd.read_csv('/home/alysha/analysis_files/S114/csv/021freq_analysis.csv')
#f12 = pd.read_csv('/home/alysha/analysis_files/S114/csv/022freq_analysis.csv')
#f13 = pd.read_csv('/home/alysha/analysis_files/S114/csv/023freq_analysis.csv')
#f14 = pd.read_csv('/home/alysha/analysis_files/S114/csv/024freq_analysis.csv')
#f15 = pd.read_csv('/home/alysha/analysis_files/S114/csv/025freq_analysis.csv')              
#f16 = pd.read_csv('/home/alysha/analysis_files/S114/csv/026freq_analysis.csv')
#f17 = pd.read_csv('/home/alysha/analysis_files/S114/csv/027freq_analysis.csv')
#f18 = pd.read_csv('/home/alysha/analysis_files/S114/csv/028freq_analysis.csv')
#f19 = pd.read_csv('/home/alysha/analysis_files/S114/csv/029freq_analysis.csv')
f20 = pd.read_csv('/home/alysha/analysis_files/S114/csv/030freq_analysis.csv')
f21 = pd.read_csv('/home/alysha/analysis_files/S114/csv/031freq_analysis.csv')    
f22 = pd.read_csv('/home/alysha/analysis_files/S114/csv/032freq_analysis.csv')
f23 = pd.read_csv('/home/alysha/analysis_files/S114/csv/033freq_analysis.csv')
f24 = pd.read_csv('/home/alysha/analysis_files/S114/csv/034freq_analysis.csv')
f25 = pd.read_csv('/home/alysha/analysis_files/S114/csv/035freq_analysis.csv')                 
f26 = pd.read_csv('/home/alysha/analysis_files/S114/csv/036freq_analysis.csv')
f27 = pd.read_csv('/home/alysha/analysis_files/S114/csv/037freq_analysis.csv')
f28 = pd.read_csv('/home/alysha/analysis_files/S114/csv/038freq_analysis.csv')
f29 = pd.read_csv('/home/alysha/analysis_files/S114/csv/039freq_analysis.csv')
#f30 = pd.read_csv('/home/alysha/analysis_files/S114/csv/040freq_analysis.csv')
#f31 = pd.read_csv('/home/alysha/analysis_files/S114/csv/041freq_analysis.csv')    
#f32 = pd.read_csv('/home/alysha/analysis_files/S114/csv/042freq_analysis.csv')
#f33 = pd.read_csv('/home/alysha/analysis_files/S114/csv/043freq_analysis.csv')
#f34 = pd.read_csv('/home/alysha/analysis_files/S114/csv/044freq_analysis.csv')
#f35 = pd.read_csv('/home/alysha/analysis_files/S114/csv/045freq_analysis.csv')                 
#f36 = pd.read_csv('/home/alysha/analysis_files/S114/csv/046freq_analysis.csv')
#f37 = pd.read_csv('/home/alysha/analysis_files/S114/csv/047freq_analysis.csv')
#f38 = pd.read_csv('/home/alysha/analysis_files/S114/csv/048freq_analysis.csv')
#f39 = pd.read_csv('/home/alysha/analysis_files/S114/csv/049freq_analysis.csv')
#f40 = pd.read_csv('/home/alysha/analysis_files/S114/csv/050freq_analysis.csv')
'''
f41 = pd.read_csv('/home/alysha/analysis_files/S114/csv/051freq_analysis.csv')
f42 = pd.read_csv('/home/alysha/analysis_files/S114/csv/052freq_analysis.csv')
f43 = pd.read_csv('/home/alysha/analysis_files/S114/csv/053freq_analysis.csv')
f44 = pd.read_csv('/home/alysha/analysis_files/S114/csv/054freq_analysis.csv')
f45 = pd.read_csv('/home/alysha/analysis_files/S114/csv/055freq_analysis.csv')                 
f46 = pd.read_csv('/home/alysha/analysis_files/S114/csv/056freq_analysis.csv')
f47 = pd.read_csv('/home/alysha/analysis_files/S114/csv/057freq_analysis.csv')
f48 = pd.read_csv('/home/alysha/analysis_files/S114/csv/058freq_analysis.csv')
f49 = pd.read_csv('/home/alysha/analysis_files/S114/csv/059freq_analysis.csv')
'''


g0 = pd.read_csv('/home/alysha/analysis_files/S114/csv/010L_analysis.csv')
g1 = pd.read_csv('/home/alysha/analysis_files/S114/csv/011L_analysis.csv')
g2 = pd.read_csv('/home/alysha/analysis_files/S114/csv/012L_analysis.csv')
g3 = pd.read_csv('/home/alysha/analysis_files/S114/csv/013L_analysis.csv')
g4 = pd.read_csv('/home/alysha/analysis_files/S114/csv/014L_analysis.csv')
g5 = pd.read_csv('/home/alysha/analysis_files/S114/csv/015L_analysis.csv')                 
g6 = pd.read_csv('/home/alysha/analysis_files/S114/csv/016L_analysis.csv')
g7 = pd.read_csv('/home/alysha/analysis_files/S114/csv/017L_analysis.csv')
g8 = pd.read_csv('/home/alysha/analysis_files/S114/csv/018L_analysis.csv')
g9 = pd.read_csv('/home/alysha/analysis_files/S114/csv/019L_analysis.csv')
'''
g10 = pd.read_csv('/home/alysha/analysis_files/S114/csv/020L_analysis.csv')
g11 = pd.read_csv('/home/alysha/analysis_files/S114/csv/021L_analysis.csv')
g12 = pd.read_csv('/home/alysha/analysis_files/S114/csv/022L_analysis.csv')
g13 = pd.read_csv('/home/alysha/analysis_files/S114/csv/023L_analysis.csv')
g14 = pd.read_csv('/home/alysha/analysis_files/S114/csv/024L_analysis.csv')
g15 = pd.read_csv('/home/alysha/analysis_files/S114/csv/025L_analysis.csv')              
g16 = pd.read_csv('/home/alysha/analysis_files/S114/csv/026L_analysis.csv')
g17 = pd.read_csv('/home/alysha/analysis_files/S114/csv/027L_analysis.csv')
g18 = pd.read_csv('/home/alysha/analysis_files/S114/csv/028L_analysis.csv')
g19 = pd.read_csv('/home/alysha/analysis_files/S114/csv/029L_analysis.csv')
'''
g20 = pd.read_csv('/home/alysha/analysis_files/S114/csv/030L_analysis.csv')
g21 = pd.read_csv('/home/alysha/analysis_files/S114/csv/031L_analysis.csv')    
g22 = pd.read_csv('/home/alysha/analysis_files/S114/csv/032L_analysis.csv')
g23 = pd.read_csv('/home/alysha/analysis_files/S114/csv/033L_analysis.csv')
g24 = pd.read_csv('/home/alysha/analysis_files/S114/csv/034L_analysis.csv')
g25 = pd.read_csv('/home/alysha/analysis_files/S114/csv/035L_analysis.csv')                 
g26 = pd.read_csv('/home/alysha/analysis_files/S114/csv/036L_analysis.csv')
g27 = pd.read_csv('/home/alysha/analysis_files/S114/csv/037L_analysis.csv')
g28 = pd.read_csv('/home/alysha/analysis_files/S114/csv/038L_analysis.csv')
g29 = pd.read_csv('/home/alysha/analysis_files/S114/csv/039L_analysis.csv')
'''
g30 = pd.read_csv('/home/alysha/analysis_files/S114/csv/040L_analysis.csv')
g31 = pd.read_csv('/home/alysha/analysis_files/S114/csv/041L_analysis.csv')    
g32 = pd.read_csv('/home/alysha/analysis_files/S114/csv/042L_analysis.csv')
g33 = pd.read_csv('/home/alysha/analysis_files/S114/csv/043L_analysis.csv')
g34 = pd.read_csv('/home/alysha/analysis_files/S114/csv/044L_analysis.csv')
g35 = pd.read_csv('/home/alysha/analysis_files/S114/csv/045L_analysis.csv')                 
g36 = pd.read_csv('/home/alysha/analysis_files/S114/csv/046L_analysis.csv')
g37 = pd.read_csv('/home/alysha/analysis_files/S114/csv/047L_analysis.csv')
g38 = pd.read_csv('/home/alysha/analysis_files/S114/csv/048L_analysis.csv')
g39 = pd.read_csv('/home/alysha/analysis_files/S114/csv/049L_analysis.csv')

g40 = pd.read_csv('/home/alysha/analysis_files/S114/csv/050L_analysis.csv')
g41 = pd.read_csv('/home/alysha/analysis_files/S114/csv/051L_analysis.csv')
g42 = pd.read_csv('/home/alysha/analysis_files/S114/csv/052L_analysis.csv')
g43 = pd.read_csv('/home/alysha/analysis_files/S114/csv/053L_analysis.csv')
g44 = pd.read_csv('/home/alysha/analysis_files/S114/csv/054L_analysis.csv')
g45 = pd.read_csv('/home/alysha/analysis_files/S114/csv/055L_analysis.csv')                 
g46 = pd.read_csv('/home/alysha/analysis_files/S114/csv/056L_analysis.csv')
g47 = pd.read_csv('/home/alysha/analysis_files/S114/csv/057L_analysis.csv')
g48 = pd.read_csv('/home/alysha/analysis_files/S114/csv/058L_analysis.csv')
g49 = pd.read_csv('/home/alysha/analysis_files/S114/csv/059L_analysis.csv')
'''

h0 = pd.read_csv('/home/alysha/analysis_files/S114/csv/010R_analysis.csv')
h1 = pd.read_csv('/home/alysha/analysis_files/S114/csv/011R_analysis.csv')
h2 = pd.read_csv('/home/alysha/analysis_files/S114/csv/012R_analysis.csv')
h3 = pd.read_csv('/home/alysha/analysis_files/S114/csv/013R_analysis.csv')
h4 = pd.read_csv('/home/alysha/analysis_files/S114/csv/014R_analysis.csv')
h5 = pd.read_csv('/home/alysha/analysis_files/S114/csv/015R_analysis.csv')                 
h6 = pd.read_csv('/home/alysha/analysis_files/S114/csv/016R_analysis.csv')
h7 = pd.read_csv('/home/alysha/analysis_files/S114/csv/017R_analysis.csv')
h8 = pd.read_csv('/home/alysha/analysis_files/S114/csv/018R_analysis.csv')
h9 = pd.read_csv('/home/alysha/analysis_files/S114/csv/019R_analysis.csv')
'''
h10 = pd.read_csv('/home/alysha/analysis_files/S114/csv/020R_analysis.csv')
h11 = pd.read_csv('/home/alysha/analysis_files/S114/csv/021R_analysis.csv')
h12 = pd.read_csv('/home/alysha/analysis_files/S114/csv/022R_analysis.csv')
h13 = pd.read_csv('/home/alysha/analysis_files/S114/csv/023R_analysis.csv')
h14 = pd.read_csv('/home/alysha/analysis_files/S114/csv/024R_analysis.csv')
h15 = pd.read_csv('/home/alysha/analysis_files/S114/csv/025R_analysis.csv')              
h16 = pd.read_csv('/home/alysha/analysis_files/S114/csv/026R_analysis.csv')
h17 = pd.read_csv('/home/alysha/analysis_files/S114/csv/027R_analysis.csv')
h18 = pd.read_csv('/home/alysha/analysis_files/S114/csv/028R_analysis.csv')
h19 = pd.read_csv('/home/alysha/analysis_files/S114/csv/029R_analysis.csv')
'''
h20 = pd.read_csv('/home/alysha/analysis_files/S114/csv/030R_analysis.csv')
h21 = pd.read_csv('/home/alysha/analysis_files/S114/csv/031R_analysis.csv')    
h22 = pd.read_csv('/home/alysha/analysis_files/S114/csv/032R_analysis.csv')
h23 = pd.read_csv('/home/alysha/analysis_files/S114/csv/033R_analysis.csv')
h24 = pd.read_csv('/home/alysha/analysis_files/S114/csv/034R_analysis.csv')
h25 = pd.read_csv('/home/alysha/analysis_files/S114/csv/035R_analysis.csv')                 
h26 = pd.read_csv('/home/alysha/analysis_files/S114/csv/036R_analysis.csv')
h27 = pd.read_csv('/home/alysha/analysis_files/S114/csv/037R_analysis.csv')
h28 = pd.read_csv('/home/alysha/analysis_files/S114/csv/038R_analysis.csv')
h29 = pd.read_csv('/home/alysha/analysis_files/S114/csv/039R_analysis.csv')

'''
h30 = pd.read_csv('/home/alysha/analysis_files/S114/csv/040R_analysis.csv')
h31 = pd.read_csv('/home/alysha/analysis_files/S114/csv/041R_analysis.csv')    
h32 = pd.read_csv('/home/alysha/analysis_files/S114/csv/042R_analysis.csv')
h33 = pd.read_csv('/home/alysha/analysis_files/S114/csv/043R_analysis.csv')
h34 = pd.read_csv('/home/alysha/analysis_files/S114/csv/044R_analysis.csv')
h35 = pd.read_csv('/home/alysha/analysis_files/S114/csv/045R_analysis.csv')                 
h36 = pd.read_csv('/home/alysha/analysis_files/S114/csv/046R_analysis.csv')
h37 = pd.read_csv('/home/alysha/analysis_files/S114/csv/047R_analysis.csv')
h38 = pd.read_csv('/home/alysha/analysis_files/S114/csv/048R_analysis.csv')
h39 = pd.read_csv('/home/alysha/analysis_files/S114/csv/049R_analysis.csv')
h40 = pd.read_csv('/home/alysha/analysis_files/S114/csv/050R_analysis.csv')
h41 = pd.read_csv('/home/alysha/analysis_files/S114/csv/051R_analysis.csv')
h42 = pd.read_csv('/home/alysha/analysis_files/S114/csv/052R_analysis.csv')
h43 = pd.read_csv('/home/alysha/analysis_files/S114/csv/053R_analysis.csv')
h44 = pd.read_csv('/home/alysha/analysis_files/S114/csv/054R_analysis.csv')
h45 = pd.read_csv('/home/alysha/analysis_files/S114/csv/055R_analysis.csv')                 
h46 = pd.read_csv('/home/alysha/analysis_files/S114/csv/056R_analysis.csv')
h47 = pd.read_csv('/home/alysha/analysis_files/S114/csv/057R_analysis.csv')
h48 = pd.read_csv('/home/alysha/analysis_files/S114/csv/058R_analysis.csv')
h49 = pd.read_csv('/home/alysha/analysis_files/S114/csv/059R_analysis.csv')

'''


#f50 = pd.read_csv('010freq_analysis.csv')
#f51 = pd.read_csv('011freq_analysis.csv')
#f52 = pd.read_csv('012freq_analysis.csv')
#f53 = pd.read_csv('012freq_analysis.csv')
#f54 = pd.read_csv('013freq_analysis.csv')
#f55 = pd.read_csv('014freq_analysis.csv')                 
#f56 = pd.read_csv('010freq_analysis.csv')
#f57 = pd.read_csv('011freq_analysis.csv')
#f58 = pd.read_csv('012freq_analysis.csv')
#f59 = pd.read_csv('012freq_analysis.csv')
#f50 = pd.read_csv('013freq_analysis.csv')


#all_lamp = [f1['0'], f2['0'],f3['0'], f4['0'], f5['0'], f6['0'], f7['0'], 
#            f8['0'], f9['0']] #f10['0'], f11['0'], f12['0'], f13['0'], 
#            #f14['0'], f15['0'], f16['0'], f17['0'], f18['0'], f19['0'], f20['0']]
#all_lamp = [f10['0'], f11['0'], f12['0'], f13['0'], f14['0'], f15['0'], f16['0'], f17['0'], 
#            f18['0'], f19['0']]
            #f30['0'], f31['0'], f32['0'], f33['0'], f34['0'], f35['0'], f36['0'], f37['0'], 
            #f38['0'], f39['0'],
            #f50['0'], f51['0'], f52['0'], f53['0'], f54['0'], f55['0'], f56['0'], f57['0'], 
            #f58['0'], f59['0'],
            #f70['0'], f71['0'], f72['0'], f73['0'], f74['0'], f75['0'], f76['0'], f77['0'], 
            #f78['0'], f79['0']]
            #f90['0'], f91['0'], f92['0'], f93['0'], f94['0'], f95['0'], f96['0'], f97['0'], 
            #f98['0'], f99['0']]

'''
#compute mean and downsample by one-tenth for use in illustrator
lamp_means = np.mean(all_lamp,axis = 0)
lamp_means = lamp_means[0:len(lamp_means):10]
lamp_error = stats.sem(all_lamp,axis = 0)
lamp_error = lamp_error[0:len(lamp_error):10]

#plt.figure(2)
plt.rc('font', size=12)
plt.rc('axes',linewidth=.5)
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.major.size'] = 2
plt.rcParams['ytick.major.size'] = 2
plt.rcParams['axes.linewidth'] = 2

fs_axon = 1.0/2000.0
t= np.linspace(0,len(lamp_means)/(1/fs_axon),len(lamp_means))

fig = plt.figure(figsize=(4,8))
fig.set_facecolor('w')

ax = fig.add_subplot(211)
ax.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
#ax.plot(t[1::20],lamp_means[1::20], 'k')
ax.plot(t[1::20],y[1::20], 'k')
ax.fill_between(t[1::20],lamp_means[1::20]+lamp_error[1::20], lamp_means[1::20]-lamp_error[1::20],color='k', alpha = 0.3, edgecolor = 'none')


ax.set_ylabel('WBA (rel. units)')
ax.spines['left'].set_bounds(0, .2)
#ax.set_ylim((-.75, .75))
ax.set_ylim((470, 510))
ax.set_xlim((0.5, 3.0))
#ax.set_yticks([0, .2])
#ax.set_xticks([])
ax.tick_params(axis='both', which='major', pad=2)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
'''


'''
('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t16/wbf_means.csv')
f17 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t17/wbf_means.csv')
f18 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t18/wbf_means.csv')
f19 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t19/wbf_means.csv')
f20 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t20/wbf_means.csv')
'''

#[f1['0'], f2['0'],f3['0'], f4['0'], f5['0'], f6['0'],
all_wbf = [ f0['0'], f1['0'], f2['0'],f3['0'], f4['0'], f5['0'], f6['0'], f7['0'], 
            f8['0'], f9['0'],
            #f10['0'], f12['0'],f13['0'], f14['0'], f15['0'], f16['0'], f17['0'], 
            #f18['0'], f19['0'],
            f20['0'], f21['0'], f22['0'],f23['0'], f24['0'], f25['0'], f26['0'], f27['0'], 
            f28['0'], f29['0']] 
            #f30['0'], f31['0'], f32['0'],f33['0'], f34['0'], f35['0'], f36['0'], f37['0'], 
            #f38['0'], f39['0'], 
            #f40['0'], f41['0'], f42['0'],f43['0'], f44['0'], f45['0'], f46['0'], f47['0'], 
            #f48['0'], f49['0']]
            #f50['0'], f51['0'], f52['0'], f53['0'], f54['0'], f55['0'], f56['0'], f57['0'], 
            #f58['0'], f59['0'],
            #f60['0'], f61['0'], f62['0'],f63['0'], f64['0'], f65['0'], f66['0'], f67['0'], 
            #f68['0'], f69['0'],
            #f70['0'], f71['0'], f72['0'], f73['0'], f74['0'], f75['0'], f76['0'], f77['0'], 
            #f78['0'], f79['0'],
            #f80['0'], f81['0'], f82['0'],f83['0'], f84['0'], f85['0'], f86['0'], f87['0'], 
            #f88['0'], f89['0']]

#plt.figure(2)
plt.rc('font', size=12)
plt.rc('axes',linewidth=.5)
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.major.size'] = 2
plt.rcParams['ytick.major.size'] = 2
plt.rcParams['axes.linewidth'] = 2

wbf_means = np.mean(all_wbf,axis = 0)
wbf_means = wbf_means[0:len(wbf_means):10]
wbf_error = stats.sem(all_wbf,axis = 0)
wbf_error = wbf_error[0:len(wbf_error):10]

fs_axon = 1.0/2000.0
t= np.linspace(0,len(wbf_means)/(1/fs_axon),len(wbf_means))


fig = plt.figure(figsize=(4,8))
fig.set_facecolor('w')


ax2 = fig.add_subplot(212)

#ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.plot(t,wbf_means*100, 'k')
ax2.fill_between(t,wbf_means*100+wbf_error*100, wbf_means*100-wbf_error*100,color='k', alpha = 0.3, edgecolor = 'none')

ax2.set_ylabel(r'$\Delta$''WBF (Hz)')
#ax2.spines['left'].set_bounds(180, 190)
#ax2.spines['bottom'].set_bounds(0.25, .75)
#ax2.set_xlim((0.5, 3.0))
#ax2.set_yticks([180, 190])
#ax2.set_xticks([.25, .75])
#ax2.tick_params(axis='both', which='major', pad=2)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
#ax2.spines['bottom'].set_visible(False)

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

#plt.savefig('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/' + 'WBA_WBF_summ.pdf', format = 'pdf', dpi = 300)
'''
#%%
plt.figure(2)
plt.plot(lamp_means, wbf_means, 'r.')
#plt.fill_between(lamp_means,wbf_means+wbf_error, wbf_means-wbf_error,color='k', alpha = 0.3, edgecolor = 'none')
#plt.fill_betweenx(wbf_means, lamp_means+lamp_error, lamp_means-lamp_error,color='k', alpha = 0.3, edgecolor = 'none')
'''

#fname = 'fly%s-%s-%s-summary.svg'%('summary',signal[0],signal[1])
fname = 'summary_signals_WBF_WSA_S110.pdf'
figure.savefig(fname, format='svg')
figure.savefig(fname, format='pdf')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-34-5471c96baa0f> in <module>()
#     499 #fname = 'fly%s-%s-%s-summary.svg'%('summary',signal[0],signal[1])
#     500 fname = 'summary_signals_WBF_WSA_S110.pdf'
# --> 501 figure.savefig(fname, format='svg')
#     502 figure.savefig(fname, format='pdf')
#
# NameError: name 'figure' is not defined

# %%
len(wbf_means)
len(t)
# Out:
# 6000

# %%
# Out:
# pandas.core.series.Series

# %%
non_flight_epochs = []
flight_epochs = []

flight_trials_wbf = pd.DataFrame()


for i in range(len(all_wbf)):
    s = all_wbf[i][100:60000]*100
    if (s < 100).any():
        non_flight_epochs.append(i)
    else: 
        flight_epochs.append(i)
        flight_trials_wbf[i] = all_wbf[i]
        
print non_flight_epochs
# Out:
# [2, 4, 6, 7, 8, 9, 10, 11]

# %%
flight_trials_wbf.head()
# Out:
#          0         1         3         5         12        13        14  \
# 0  2.061157  2.037964  2.070007  2.055359  2.129211  2.066956  2.131653
# 1  2.060547  2.037964  2.070007  2.055664  2.129211  2.068176  2.131348
# 2  2.061462  2.037354  2.070007  2.056580  2.129822  2.067566  2.131042
# 3  2.061768  2.037048  2.069702  2.056274  2.129211  2.066956  2.131958
# 4  2.061157  2.037354  2.070312  2.055969  2.127991  2.066956  2.131348
#
#          15        16        17        18        19
# 0  2.077637  1.952515  2.122192  2.066956  2.084351
# 1  2.077026  1.951599  2.122192  2.067871  2.083740
# 2  2.078247  1.951294  2.122803  2.067261  2.085571
# 3  2.078247  1.952515  2.122803  2.066650  2.084656
# 4  2.077637  1.951599  2.121582  2.066650  2.084351

# %% [markdown]
# fig = plt.figure(figsize=(4,8))
# fig.set_facecolor('w')
#
#
#
# ax2 = fig.add_subplot(212)
#
# #ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
# ax2.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
# ax2.plot(t,f9[::10]*100, 'k')
#
# ax2.set_ylabel(r'$\Delta$''WBF (hz) ')
#
# ax2.spines['top'].set_visible(False)
# ax2.spines['right'].set_visible(False)
# #ax2.spines['bottom'].set_visible(False)
#
# ax2.xaxis.set_ticks_position('bottom')
# ax2.yaxis.set_ticks_position('left')
#
# plt.show()

# %%
for i in flight_trials_wbf:

    fig = plt.figure(figsize=(4,8))
    fig.set_facecolor('w')



    ax2 = fig.add_subplot(212)

    #ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
    ax2.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
    ax2.plot(t,flight_trials_wbf[i][::10]*100, 'k')

    ax2.set_ylabel(r'$\Delta$''WBF (hz) ')
    ax2.set_ylim(160,220)
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    #ax2.spines['bottom'].set_visible(False)

    ax2.xaxis.set_ticks_position('bottom')
    ax2.yaxis.set_ticks_position('left')

    plt.show()

# %%
#plt.figure(2)
plt.rc('font', size=12)
plt.rc('axes',linewidth=.5)
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.major.size'] = 2
plt.rcParams['ytick.major.size'] = 2
plt.rcParams['axes.linewidth'] = 2


fs_axon = 1.0/2000.0
t= np.linspace(0,len(wbf_means)/(1/fs_axon),len(wbf_means))


wbf_means = np.median(flight_trials_wbf,axis = 1)
wbf_means = wbf_means[0:len(wbf_means):10]
wbf_error = stats.sem(flight_trials_wbf,axis = 1)
wbf_error = wbf_error[0:len(wbf_error):10]



fs_axon = 1.0/2000.0
t= np.linspace(0,len(wbf_means)/(1/fs_axon),len(wbf_means))



fig = plt.figure(figsize=(4,8))
fig.set_facecolor('w')


ax2 = fig.add_subplot(212)

#ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.plot(t,wbf_means*100, 'k')
ax2.fill_between(t,wbf_means*100+wbf_error*100, wbf_means*100-wbf_error*100,color='k', alpha = 0.3, edgecolor = 'none')

ax2.set_ylabel(r'$\Delta$''WBF (Hz)')
#ax2.spines['left'].set_bounds(180, 190)
#ax2.spines['bottom'].set_bounds(0.25, .75)
#ax2.set_xlim((0.5, 3.0))
#ax2.set_yticks([180, 190])
#ax2.set_xticks([.25, .75])
#ax2.tick_params(axis='both', which='major', pad=2)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
#ax2.spines['bottom'].set_visible(False)

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

#plt.savefig('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/' + 'WBA_WBF_summ.pdf', format = 'pdf', dpi = 300)
'''
#%%
plt.figure(2)
plt.plot(lamp_means, wbf_means, 'r.')
#plt.fill_between(lamp_means,wbf_means+wbf_error, wbf_means-wbf_error,color='k', alpha = 0.3, edgecolor = 'none')
#plt.fill_betweenx(wbf_means, lamp_means+lamp_error, lamp_means-lamp_error,color='k', alpha = 0.3, edgecolor = 'none')
'''

#fname = 'fly%s-%s-%s-summary.svg'%('summary',signal[0],signal[1])
fname = 'summary_signals_WBF_WSA_S110.pdf'
figure.savefig(fname, format='svg')
figure.savefig(fname, format='pdf')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-40-d2013bb74d7c> in <module>()
#      62 #fname = 'fly%s-%s-%s-summary.svg'%('summary',signal[0],signal[1])
#      63 fname = 'summary_signals_WBF_WSA_S110.pdf'
# ---> 64 figure.savefig(fname, format='svg')
#      65 figure.savefig(fname, format='pdf')
#
# NameError: name 'figure' is not defined

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Mar 21 15:47:34 2018

@author: alyshadesouza
"""
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy import stats
from IPython.display import SVG,display

'''
f1 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t1/lamp_means.csv')
f2 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t2/lamp_means.csv')
f3 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t3/lamp_means.csv')
f4 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t4/lamp_means.csv')
f5 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t5/lamp_means.csv')
f6 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t6/lamp_means.csv')
f7 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t7/lamp_means.csv')

f8 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t8/lamp_means.csv')
f9 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t9/lamp_means.csv')
f10 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t10/lamp_means.csv')
f11 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t11/lamp_means.csv')
f12 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t12/lamp_means.csv')
f13 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t13/lamp_means.csv')
f14 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t14/lamp_means.csv')
f15 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t15/lamp_means.csv')
#
f16 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t16/lamp_means.csv')
f17 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t17/lamp_means.csv')
f18 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t18/lamp_means.csv')
f19 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t19/lamp_means.csv')
f20 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t20/lamp_means.csv')
'''
'''
f0 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/0freq_analysis.csv')
f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/1freq_analysis.csv')
f2 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/2freq_analysis.csv')
f3 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/3freq_analysis.csv')
f4 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/4freq_analysis.csv')
f5 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/5freq_analysis.csv')
f6 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/6freq_analysis.csv')
f7 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/7freq_analysis.csv')
f8 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/8freq_analysis.csv')
f9 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/9freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')

f20 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/0freq_analysis.csv')
f21 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/1freq_analysis.csv')
f22 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/2freq_analysis.csv')
f23 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/3freq_analysis.csv')
f24 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/4freq_analysis.csv')
f25 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/5freq_analysis.csv')
f26 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/6freq_analysis.csv')
f27 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/7freq_analysis.csv')
f28 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/8freq_analysis.csv')
f29 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/9freq_analysis.csv')

f40 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/0freq_analysis.csv')
f41 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/1freq_analysis.csv')
f42 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/2freq_analysis.csv')
f43 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/3freq_analysis.csv')
f44 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/4freq_analysis.csv')
f45 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/5freq_analysis.csv')
f46 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/6freq_analysis.csv')
f47 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/7freq_analysis.csv')
f48 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/8freq_analysis.csv')
f49 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/9freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')
#f1 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0freq_analysis.csv')

f60 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/0freq_analysis.csv')
f61 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/1freq_analysis.csv')
f62 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/2freq_analysis.csv')
f63 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/3freq_analysis.csv')
f64 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/4freq_analysis.csv')
f65 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/5freq_analysis.csv')
f66 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/6freq_analysis.csv')
f67 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/7freq_analysis.csv')
f68 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/8freq_analysis.csv')
f69 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/9freq_analysis.csv')

f80 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/0freq_analysis.csv')
f81 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/1freq_analysis.csv')
f82 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/2freq_analysis.csv')
f83 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/3freq_analysis.csv')
f84 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/4freq_analysis.csv')
f85 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/5freq_analysis.csv')
f86 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/6freq_analysis.csv')
f87 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/7freq_analysis.csv')
f88 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/8freq_analysis.csv')
f89 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/9freq_analysis.csv')
'''
'''
f10 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/0WSA_analysis.csv')
f11 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/1WSA_analysis.csv')
f12 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/2WSA_analysis.csv')
f13 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/3WSA_analysis.csv')
f14 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/4WSA_analysis.csv')
f15 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/5WSA_analysis.csv')
f16 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/6WSA_analysis.csv')
f17 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/7WSA_analysis.csv')
f18 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/8WSA_analysis.csv')
f19 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S016/9WSA_analysis.csv')

'''
'''
f10 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/0WSA_analysis.csv')
f11 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/1WSA_analysis.csv')
f12 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/2WSA_analysis.csv')
f13 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/3WSA_analysis.csv')
f14 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/4WSA_analysis.csv')
f15 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/5WSA_analysis.csv')
f16 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/6WSA_analysis.csv')
f17 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/7WSA_analysis.csv')
f18 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/8WSA_analysis.csv')
f19 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_0/9WSA_analysis.csv')

'''
'''
f30 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/0WSA_analysis.csv')
f31 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/1WSA_analysis.csv')
f32 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/2WSA_analysis.csv')
f33 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/3WSA_analysis.csv')
f34 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/4WSA_analysis.csv')
f35 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/5WSA_analysis.csv')
f36 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/6WSA_analysis.csv')
f37 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/7WSA_analysis.csv')
f38 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/8WSA_analysis.csv')
f39 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_1/9WSA_analysis.csv')

f50 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/0WSA_analysis.csv')
f51 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/1WSA_analysis.csv')
f52 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/2WSA_analysis.csv')
f53 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/3WSA_analysis.csv')
f54 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/4WSA_analysis.csv')
f55 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/5WSA_analysis.csv')
f56 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/6WSA_analysis.csv')
f57 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/7WSA_analysis.csv')
f58 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/8WSA_analysis.csv')
f59 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_2/9WSA_analysis.csv')

f70 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/0WSA_analysis.csv')
f71 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/1WSA_analysis.csv')
f72 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/2WSA_analysis.csv')
f73 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/3WSA_analysis.csv')
f74 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/4WSA_analysis.csv')
f75 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/5WSA_analysis.csv')
f76 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/6WSA_analysis.csv')
f77 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/7WSA_analysis.csv')
f78 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/8WSA_analysis.csv')
f79 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_3/9WSA_analysis.csv')

f90 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/0WSA_analysis.csv')
f91 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/1WSA_analysis.csv')
f92 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/2WSA_analysis.csv')
f93 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/3WSA_analysis.csv')
f94 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/4WSA_analysis.csv')
f95 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/5WSA_analysis.csv')
f96 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/6WSA_analysis.csv')
f97 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/7WSA_analysis.csv')
f98 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/8WSA_analysis.csv')
f99 = pd.read_csv('/home/alysha/media/imager/FlyDataD/lysh_ephys_ata_old/S248_5/9WSA_analysis.csv')




'''



'''
f0 = pd.read_csv('/home/alysha/analysis_files/S104/csv/010freq_analysis.csv')
f1 = pd.read_csv('/home/alysha/analysis_files/S104/csv/011freq_analysis.csv')
f2 = pd.read_csv('/home/alysha/analysis_files/S104/csv/012freq_analysis.csv')
f3 = pd.read_csv('/home/alysha/analysis_files/S104/csv/013freq_analysis.csv')
f4 = pd.read_csv('/home/alysha/analysis_files/S104/csv/014freq_analysis.csv')
f5 = pd.read_csv('/home/alysha/analysis_files/S104/csv/015freq_analysis.csv')                 
f6 = pd.read_csv('/home/alysha/analysis_files/S104/csv/016freq_analysis.csv')
f7 = pd.read_csv('/home/alysha/analysis_files/S104/csv/017freq_analysis.csv')
f8 = pd.read_csv('/home/alysha/analysis_files/S104/csv/018freq_analysis.csv')
f9 = pd.read_csv('/home/alysha/analysis_files/S104/csv/019freq_analysis.csv')
f10 = pd.read_csv('/home/alysha/analysis_files/S104/csv/020freq_analysis.csv')
f11 = pd.read_csv('/home/alysha/analysis_files/S104/csv/021freq_analysis.csv')
f12 = pd.read_csv('/home/alysha/analysis_files/S104/csv/022freq_analysis.csv')
f13 = pd.read_csv('/home/alysha/analysis_files/S104/csv/023freq_analysis.csv')
f14 = pd.read_csv('/home/alysha/analysis_files/S104/csv/024freq_analysis.csv')
f15 = pd.read_csv('/home/alysha/analysis_files/S104/csv/025freq_analysis.csv')              
f16 = pd.read_csv('/home/alysha/analysis_files/S104/csv/026freq_analysis.csv')
f17 = pd.read_csv('/home/alysha/analysis_files/S104/csv/027freq_analysis.csv')
f18 = pd.read_csv('/home/alysha/analysis_files/S104/csv/028freq_analysis.csv')
f19 = pd.read_csv('/home/alysha/analysis_files/S104/csv/029freq_analysis.csv')
f20 = pd.read_csv('/home/alysha/analysis_files/S104/csv/030freq_analysis.csv')
f21 = pd.read_csv('/home/alysha/analysis_files/S104/csv/031freq_analysis.csv')    
f22 = pd.read_csv('/home/alysha/analysis_files/S104/csv/032freq_analysis.csv')
f23 = pd.read_csv('/home/alysha/analysis_files/S104/csv/033freq_analysis.csv')
f24 = pd.read_csv('/home/alysha/analysis_files/S104/csv/034freq_analysis.csv')
f25 = pd.read_csv('/home/alysha/analysis_files/S104/csv/035freq_analysis.csv')                 
f26 = pd.read_csv('/home/alysha/analysis_files/S104/csv/036freq_analysis.csv')
f27 = pd.read_csv('/home/alysha/analysis_files/S104/csv/037freq_analysis.csv')
f28 = pd.read_csv('/home/alysha/analysis_files/S104/csv/038freq_analysis.csv')
f29 = pd.read_csv('/home/alysha/analysis_files/S104/csv/039freq_analysis.csv')
f30 = pd.read_csv('/home/alysha/analysis_files/S104/csv/040freq_analysis.csv')
f31 = pd.read_csv('/home/alysha/analysis_files/S104/csv/041freq_analysis.csv')    
f32 = pd.read_csv('/home/alysha/analysis_files/S104/csv/042freq_analysis.csv')
f33 = pd.read_csv('/home/alysha/analysis_files/S104/csv/043freq_analysis.csv')
f34 = pd.read_csv('/home/alysha/analysis_files/S104/csv/044freq_analysis.csv')
f35 = pd.read_csv('/home/alysha/analysis_files/S104/csv/045freq_analysis.csv')                 
f36 = pd.read_csv('/home/alysha/analysis_files/S104/csv/046freq_analysis.csv')
f37 = pd.read_csv('/home/alysha/analysis_files/S104/csv/047freq_analysis.csv')
f38 = pd.read_csv('/home/alysha/analysis_files/S104/csv/048freq_analysis.csv')
f39 = pd.read_csv('/home/alysha/analysis_files/S104/csv/049freq_analysis.csv')
f40 = pd.read_csv('/home/alysha/analysis_files/S104/csv/050freq_analysis.csv')
f41 = pd.read_csv('/home/alysha/analysis_files/S104/csv/051freq_analysis.csv')
f42 = pd.read_csv('/home/alysha/analysis_files/S104/csv/052freq_analysis.csv')
f43 = pd.read_csv('/home/alysha/analysis_files/S104/csv/053freq_analysis.csv')
f44 = pd.read_csv('/home/alysha/analysis_files/S104/csv/054freq_analysis.csv')
f45 = pd.read_csv('/home/alysha/analysis_files/S104/csv/055freq_analysis.csv')                 
f46 = pd.read_csv('/home/alysha/analysis_files/S104/csv/056freq_analysis.csv')
f47 = pd.read_csv('/home/alysha/analysis_files/S104/csv/057freq_analysis.csv')
f48 = pd.read_csv('/home/alysha/analysis_files/S104/csv/058freq_analysis.csv')
f49 = pd.read_csv('/home/alysha/analysis_files/S104/csv/059freq_analysis.csv')
'''

fs_axon = 1.0/2000.0
t= np.linspace(0,len(wbf_means)/(1/fs_axon),len(wbf_means))





f0 = pd.read_csv('/home/alysha/analysis_files/S110/csv/010freq_analysis.csv')
f1 = pd.read_csv('/home/alysha/analysis_files/S110/csv/011freq_analysis.csv')
f2 = pd.read_csv('/home/alysha/analysis_files/S110/csv/012freq_analysis.csv')
f3 = pd.read_csv('/home/alysha/analysis_files/S110/csv/013freq_analysis.csv')
f4 = pd.read_csv('/home/alysha/analysis_files/S110/csv/014freq_analysis.csv')
f5 = pd.read_csv('/home/alysha/analysis_files/S110/csv/015freq_analysis.csv')                 
f6 = pd.read_csv('/home/alysha/analysis_files/S110/csv/016freq_analysis.csv')
f7 = pd.read_csv('/home/alysha/analysis_files/S110/csv/017freq_analysis.csv')
f8 = pd.read_csv('/home/alysha/analysis_files/S110/csv/018freq_analysis.csv')
f9 = pd.read_csv('/home/alysha/analysis_files/S110/csv/019freq_analysis.csv')
f10 = pd.read_csv('/home/alysha/analysis_files/S110/csv/020freq_analysis.csv')
f11 = pd.read_csv('/home/alysha/analysis_files/S110/csv/021freq_analysis.csv')
f12 = pd.read_csv('/home/alysha/analysis_files/S110/csv/022freq_analysis.csv')
f13 = pd.read_csv('/home/alysha/analysis_files/S110/csv/023freq_analysis.csv')
f14 = pd.read_csv('/home/alysha/analysis_files/S110/csv/024freq_analysis.csv')
f15 = pd.read_csv('/home/alysha/analysis_files/S110/csv/025freq_analysis.csv')              
f16 = pd.read_csv('/home/alysha/analysis_files/S110/csv/026freq_analysis.csv')
f17 = pd.read_csv('/home/alysha/analysis_files/S110/csv/027freq_analysis.csv')
f18 = pd.read_csv('/home/alysha/analysis_files/S110/csv/028freq_analysis.csv')
f19 = pd.read_csv('/home/alysha/analysis_files/S110/csv/029freq_analysis.csv')
f20 = pd.read_csv('/home/alysha/analysis_files/S110/csv/030freq_analysis.csv')
f21 = pd.read_csv('/home/alysha/analysis_files/S110/csv/031freq_analysis.csv')    
f22 = pd.read_csv('/home/alysha/analysis_files/S110/csv/032freq_analysis.csv')
f23 = pd.read_csv('/home/alysha/analysis_files/S110/csv/033freq_analysis.csv')
f24 = pd.read_csv('/home/alysha/analysis_files/S110/csv/034freq_analysis.csv')
f25 = pd.read_csv('/home/alysha/analysis_files/S110/csv/035freq_analysis.csv')                 
f26 = pd.read_csv('/home/alysha/analysis_files/S110/csv/036freq_analysis.csv')
f27 = pd.read_csv('/home/alysha/analysis_files/S110/csv/037freq_analysis.csv')
f28 = pd.read_csv('/home/alysha/analysis_files/S110/csv/038freq_analysis.csv')
f29 = pd.read_csv('/home/alysha/analysis_files/S110/csv/039freq_analysis.csv')
f30 = pd.read_csv('/home/alysha/analysis_files/S110/csv/040freq_analysis.csv')
f31 = pd.read_csv('/home/alysha/analysis_files/S110/csv/041freq_analysis.csv')    
f32 = pd.read_csv('/home/alysha/analysis_files/S110/csv/042freq_analysis.csv')
f33 = pd.read_csv('/home/alysha/analysis_files/S110/csv/043freq_analysis.csv')
f34 = pd.read_csv('/home/alysha/analysis_files/S110/csv/044freq_analysis.csv')
f35 = pd.read_csv('/home/alysha/analysis_files/S110/csv/045freq_analysis.csv')                 
f36 = pd.read_csv('/home/alysha/analysis_files/S110/csv/046freq_analysis.csv')
f37 = pd.read_csv('/home/alysha/analysis_files/S110/csv/047freq_analysis.csv')
f38 = pd.read_csv('/home/alysha/analysis_files/S110/csv/048freq_analysis.csv')
f39 = pd.read_csv('/home/alysha/analysis_files/S110/csv/049freq_analysis.csv')
f40 = pd.read_csv('/home/alysha/analysis_files/S110/csv/050freq_analysis.csv')
f41 = pd.read_csv('/home/alysha/analysis_files/S110/csv/051freq_analysis.csv')
f42 = pd.read_csv('/home/alysha/analysis_files/S110/csv/052freq_analysis.csv')
f43 = pd.read_csv('/home/alysha/analysis_files/S110/csv/053freq_analysis.csv')
f44 = pd.read_csv('/home/alysha/analysis_files/S110/csv/054freq_analysis.csv')
f45 = pd.read_csv('/home/alysha/analysis_files/S110/csv/055freq_analysis.csv')                 
f46 = pd.read_csv('/home/alysha/analysis_files/S110/csv/056freq_analysis.csv')
f47 = pd.read_csv('/home/alysha/analysis_files/S110/csv/057freq_analysis.csv')
f48 = pd.read_csv('/home/alysha/analysis_files/S110/csv/058freq_analysis.csv')
f49 = pd.read_csv('/home/alysha/analysis_files/S110/csv/059freq_analysis.csv')



g0 = pd.read_csv('/home/alysha/analysis_files/S110/csv/010L_analysis.csv')
g1 = pd.read_csv('/home/alysha/analysis_files/S110/csv/011L_analysis.csv')
g2 = pd.read_csv('/home/alysha/analysis_files/S110/csv/012L_analysis.csv')
g3 = pd.read_csv('/home/alysha/analysis_files/S110/csv/013L_analysis.csv')
g4 = pd.read_csv('/home/alysha/analysis_files/S110/csv/014L_analysis.csv')
g5 = pd.read_csv('/home/alysha/analysis_files/S110/csv/015L_analysis.csv')                 
g6 = pd.read_csv('/home/alysha/analysis_files/S110/csv/016L_analysis.csv')
g7 = pd.read_csv('/home/alysha/analysis_files/S110/csv/017L_analysis.csv')
g8 = pd.read_csv('/home/alysha/analysis_files/S110/csv/018L_analysis.csv')
g9 = pd.read_csv('/home/alysha/analysis_files/S110/csv/019L_analysis.csv')
g10 = pd.read_csv('/home/alysha/analysis_files/S110/csv/020L_analysis.csv')
g11 = pd.read_csv('/home/alysha/analysis_files/S110/csv/021L_analysis.csv')
g12 = pd.read_csv('/home/alysha/analysis_files/S110/csv/022L_analysis.csv')
g13 = pd.read_csv('/home/alysha/analysis_files/S110/csv/023L_analysis.csv')
g14 = pd.read_csv('/home/alysha/analysis_files/S110/csv/024L_analysis.csv')
g15 = pd.read_csv('/home/alysha/analysis_files/S110/csv/025L_analysis.csv')              
g16 = pd.read_csv('/home/alysha/analysis_files/S110/csv/026L_analysis.csv')
g17 = pd.read_csv('/home/alysha/analysis_files/S110/csv/027L_analysis.csv')
g18 = pd.read_csv('/home/alysha/analysis_files/S110/csv/028L_analysis.csv')
g19 = pd.read_csv('/home/alysha/analysis_files/S110/csv/029L_analysis.csv')
g20 = pd.read_csv('/home/alysha/analysis_files/S110/csv/030L_analysis.csv')
g21 = pd.read_csv('/home/alysha/analysis_files/S110/csv/031L_analysis.csv')    
g22 = pd.read_csv('/home/alysha/analysis_files/S110/csv/032L_analysis.csv')
g23 = pd.read_csv('/home/alysha/analysis_files/S110/csv/033L_analysis.csv')
g24 = pd.read_csv('/home/alysha/analysis_files/S110/csv/034L_analysis.csv')
g25 = pd.read_csv('/home/alysha/analysis_files/S110/csv/035L_analysis.csv')                 
g26 = pd.read_csv('/home/alysha/analysis_files/S110/csv/036L_analysis.csv')
g27 = pd.read_csv('/home/alysha/analysis_files/S110/csv/037L_analysis.csv')
g28 = pd.read_csv('/home/alysha/analysis_files/S110/csv/038L_analysis.csv')
g29 = pd.read_csv('/home/alysha/analysis_files/S110/csv/039L_analysis.csv')
g30 = pd.read_csv('/home/alysha/analysis_files/S110/csv/040L_analysis.csv')
g31 = pd.read_csv('/home/alysha/analysis_files/S110/csv/041L_analysis.csv')    
g32 = pd.read_csv('/home/alysha/analysis_files/S110/csv/042L_analysis.csv')
g33 = pd.read_csv('/home/alysha/analysis_files/S110/csv/043L_analysis.csv')
g34 = pd.read_csv('/home/alysha/analysis_files/S110/csv/044L_analysis.csv')
g35 = pd.read_csv('/home/alysha/analysis_files/S110/csv/045L_analysis.csv')                 
g36 = pd.read_csv('/home/alysha/analysis_files/S110/csv/046L_analysis.csv')
g37 = pd.read_csv('/home/alysha/analysis_files/S110/csv/047L_analysis.csv')
g38 = pd.read_csv('/home/alysha/analysis_files/S110/csv/048L_analysis.csv')
g39 = pd.read_csv('/home/alysha/analysis_files/S110/csv/049L_analysis.csv')
g40 = pd.read_csv('/home/alysha/analysis_files/S110/csv/050L_analysis.csv')
g41 = pd.read_csv('/home/alysha/analysis_files/S110/csv/051L_analysis.csv')
g42 = pd.read_csv('/home/alysha/analysis_files/S110/csv/052L_analysis.csv')
g43 = pd.read_csv('/home/alysha/analysis_files/S110/csv/053L_analysis.csv')
g44 = pd.read_csv('/home/alysha/analysis_files/S110/csv/054L_analysis.csv')
g45 = pd.read_csv('/home/alysha/analysis_files/S110/csv/055L_analysis.csv')                 
g46 = pd.read_csv('/home/alysha/analysis_files/S110/csv/056L_analysis.csv')
g47 = pd.read_csv('/home/alysha/analysis_files/S110/csv/057L_analysis.csv')
g48 = pd.read_csv('/home/alysha/analysis_files/S110/csv/058L_analysis.csv')
g49 = pd.read_csv('/home/alysha/analysis_files/S110/csv/059L_analysis.csv')


h0 = pd.read_csv('/home/alysha/analysis_files/S110/csv/010R_analysis.csv')
h1 = pd.read_csv('/home/alysha/analysis_files/S110/csv/011R_analysis.csv')
h2 = pd.read_csv('/home/alysha/analysis_files/S110/csv/012R_analysis.csv')
h3 = pd.read_csv('/home/alysha/analysis_files/S110/csv/013R_analysis.csv')
h4 = pd.read_csv('/home/alysha/analysis_files/S110/csv/014R_analysis.csv')
h5 = pd.read_csv('/home/alysha/analysis_files/S110/csv/015R_analysis.csv')                 
h6 = pd.read_csv('/home/alysha/analysis_files/S110/csv/016R_analysis.csv')
h7 = pd.read_csv('/home/alysha/analysis_files/S110/csv/017R_analysis.csv')
h8 = pd.read_csv('/home/alysha/analysis_files/S110/csv/018R_analysis.csv')
h9 = pd.read_csv('/home/alysha/analysis_files/S110/csv/019R_analysis.csv')
h10 = pd.read_csv('/home/alysha/analysis_files/S110/csv/020R_analysis.csv')
h11 = pd.read_csv('/home/alysha/analysis_files/S110/csv/021R_analysis.csv')
h12 = pd.read_csv('/home/alysha/analysis_files/S110/csv/022R_analysis.csv')
h13 = pd.read_csv('/home/alysha/analysis_files/S110/csv/023R_analysis.csv')
h14 = pd.read_csv('/home/alysha/analysis_files/S110/csv/024R_analysis.csv')
h15 = pd.read_csv('/home/alysha/analysis_files/S110/csv/025R_analysis.csv')              
h16 = pd.read_csv('/home/alysha/analysis_files/S110/csv/026R_analysis.csv')
h17 = pd.read_csv('/home/alysha/analysis_files/S110/csv/027R_analysis.csv')
h18 = pd.read_csv('/home/alysha/analysis_files/S110/csv/028R_analysis.csv')
h19 = pd.read_csv('/home/alysha/analysis_files/S110/csv/029R_analysis.csv')
h20 = pd.read_csv('/home/alysha/analysis_files/S110/csv/030R_analysis.csv')
h21 = pd.read_csv('/home/alysha/analysis_files/S110/csv/031R_analysis.csv')    
h22 = pd.read_csv('/home/alysha/analysis_files/S110/csv/032R_analysis.csv')
h23 = pd.read_csv('/home/alysha/analysis_files/S110/csv/033R_analysis.csv')
h24 = pd.read_csv('/home/alysha/analysis_files/S110/csv/034R_analysis.csv')
h25 = pd.read_csv('/home/alysha/analysis_files/S110/csv/035R_analysis.csv')                 
h26 = pd.read_csv('/home/alysha/analysis_files/S110/csv/036R_analysis.csv')
h27 = pd.read_csv('/home/alysha/analysis_files/S110/csv/037R_analysis.csv')
h28 = pd.read_csv('/home/alysha/analysis_files/S110/csv/038R_analysis.csv')
h29 = pd.read_csv('/home/alysha/analysis_files/S110/csv/039R_analysis.csv')
h30 = pd.read_csv('/home/alysha/analysis_files/S110/csv/040R_analysis.csv')
h31 = pd.read_csv('/home/alysha/analysis_files/S110/csv/041R_analysis.csv')    
h32 = pd.read_csv('/home/alysha/analysis_files/S110/csv/042R_analysis.csv')
h33 = pd.read_csv('/home/alysha/analysis_files/S110/csv/043R_analysis.csv')
h34 = pd.read_csv('/home/alysha/analysis_files/S110/csv/044R_analysis.csv')
h35 = pd.read_csv('/home/alysha/analysis_files/S110/csv/045R_analysis.csv')                 
h36 = pd.read_csv('/home/alysha/analysis_files/S110/csv/046R_analysis.csv')
h37 = pd.read_csv('/home/alysha/analysis_files/S110/csv/047R_analysis.csv')
h38 = pd.read_csv('/home/alysha/analysis_files/S110/csv/048R_analysis.csv')
h39 = pd.read_csv('/home/alysha/analysis_files/S110/csv/049R_analysis.csv')
h40 = pd.read_csv('/home/alysha/analysis_files/S110/csv/050R_analysis.csv')
h41 = pd.read_csv('/home/alysha/analysis_files/S110/csv/051R_analysis.csv')
h42 = pd.read_csv('/home/alysha/analysis_files/S110/csv/052R_analysis.csv')
h43 = pd.read_csv('/home/alysha/analysis_files/S110/csv/053R_analysis.csv')
h44 = pd.read_csv('/home/alysha/analysis_files/S110/csv/054R_analysis.csv')
h45 = pd.read_csv('/home/alysha/analysis_files/S110/csv/055R_analysis.csv')                 
h46 = pd.read_csv('/home/alysha/analysis_files/S110/csv/056R_analysis.csv')
h47 = pd.read_csv('/home/alysha/analysis_files/S110/csv/057R_analysis.csv')
h48 = pd.read_csv('/home/alysha/analysis_files/S110/csv/058R_analysis.csv')
h49 = pd.read_csv('/home/alysha/analysis_files/S110/csv/059R_analysis.csv')

# %%
all_g= [ g0['0'], g1['0'], g2['0'],g3['0'], g4['0'], g5['0'], g6['0'], g7['0'], 
            g8['0'], g9['0'],
            #g10['0'], g12['0'],g13['0'], g14['0'], g15['0'], g16['0'], g17['0'], 
            #g18['0'], g19['0'],
            g20['0'], g21['0'], g22['0'],g23['0'], g24['0'], g25['0'], g26['0'], g27['0'], 
            g28['0'], g29['0']] 
            #g30['0'], g31['0'], g32['0'],g33['0'], g34['0'], g35['0'], g36['0'], g37['0'], 
            #g38['0'], g39['0'], 
            #g40['0'], g41['0'], g42['0'],g43['0'], g44['0'], g45['0'], g46['0'], g47['0'], 
            #g48['0'], g49['0']]

all_h= [ h0['0']*100, h1['0']*100, h2['0']*100,h3['0']*100, h4['0']*100, h5['0']*100, h6['0']*100, h7['0']*100, 
            h8['0']*100, h9['0']*100,
            #h10['0'], h12['0'],h13['0'], h14['0'], h15['0'], h16['0'], h17['0'], 
            #h18['0'], h19['0'],
            h20['0']*100, h21['0']*100, h22['0']*100,h23['0']*100, h24['0']*100, h25['0']*100, h26['0']*100, h27['0']*100, 
            h28['0']*100, h29['0']*100] 
            #h30['0'], h31['0'], h32['0'],h33['0'], h34['0'], h35['0'], h36['0'], h37['0'], 
            #h38['0'], h39['0'], 
            #h40['0'], h41['0'], h42['0'],h43['0'], h44['0'], h45['0'], h46['0'], h47['0'], 
            #h48['0'], h49['0']]

# %%
print(flight_epochs)
# Out:
# [0, 1, 3, 5, 12, 13, 14, 15, 16, 17, 18, 19]

# %%
f_values = pd.DataFrame()
f_flight_values = pd.DataFrame()

for i in range(0,20):
    f_values[i] = all_g[i]+all_h[i]
    if i in flight_epochs:
        f_flight_values[i] = all_g[i]+all_h[i]

f_flight_values.head()
# Out:
#           0          1          3          5          12         13  \
# 0  429.59594  541.99218  681.88477  362.45728  627.22777  688.20190
# 1  429.38232  542.11425  681.94580  360.07691  627.13623  688.26294
# 2  429.53492  541.93115  681.85425  359.37500  627.34985  688.38501
# 3  429.59594  541.87012  681.79321  359.34448  627.34985  688.29346
# 4  429.53492  542.05323  681.97632  359.31397  627.13623  688.20190
#
#           14         15         16         17         18         19
# 0  579.77294  607.57447  500.61035  696.25855  703.36913  423.95020
# 1  579.52880  607.39136  500.42725  694.39697  703.58277  423.73657
# 2  579.68140  607.60498  500.45777  694.45801  703.76587  424.01124
# 3  579.77294  607.63550  500.61035  694.33592  703.58277  424.07226
# 4  579.68140  607.42188  500.51880  694.15283  703.70482  423.91968

# %%
fig = plt.figure(figsize=(4,8))
fig.set_facecolor('w')



ax2 = fig.add_subplot(212)

#ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.plot(t,f_values[6][::10], 'k')

ax2.set_ylabel(r'$\Delta$''WBA ')

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
#ax2.spines['bottom'].set_visible(False)

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

plt.show()

# %%
#f50 = pd.read_csv('010freq_analysis.csv')
#f51 = pd.read_csv('011freq_analysis.csv')
#f52 = pd.read_csv('012freq_analysis.csv')
#f53 = pd.read_csv('012freq_analysis.csv')
#f54 = pd.read_csv('013freq_analysis.csv')
#f55 = pd.read_csv('014freq_analysis.csv')                 
#f56 = pd.read_csv('010freq_analysis.csv')
#f57 = pd.read_csv('011freq_analysis.csv')
#f58 = pd.read_csv('012freq_analysis.csv')
#f59 = pd.read_csv('012freq_analysis.csv')
#f50 = pd.read_csv('013freq_analysis.csv')


#all_lamp = [f1['0'], f2['0'],f3['0'], f4['0'], f5['0'], f6['0'], f7['0'], 
#            f8['0'], f9['0']] #f10['0'], f11['0'], f12['0'], f13['0'], 
#            #f14['0'], f15['0'], f16['0'], f17['0'], f18['0'], f19['0'], f20['0']]
#all_lamp = [f10['0'], f11['0'], f12['0'], f13['0'], f14['0'], f15['0'], f16['0'], f17['0'], 
#            f18['0'], f19['0']]
            #f30['0'], f31['0'], f32['0'], f33['0'], f34['0'], f35['0'], f36['0'], f37['0'], 
            #f38['0'], f39['0'],
            #f50['0'], f51['0'], f52['0'], f53['0'], f54['0'], f55['0'], f56['0'], f57['0'], 
            #f58['0'], f59['0'],
            #f70['0'], f71['0'], f72['0'], f73['0'], f74['0'], f75['0'], f76['0'], f77['0'], 
            #f78['0'], f79['0']]
            #f90['0'], f91['0'], f92['0'], f93['0'], f94['0'], f95['0'], f96['0'], f97['0'], 
            #f98['0'], f99['0']]

'''
#compute mean and downsample by one-tenth for use in illustrator
lamp_means = np.mean(all_lamp,axis = 0)
lamp_means = lamp_means[0:len(lamp_means):10]
lamp_error = stats.sem(all_lamp,axis = 0)
lamp_error = lamp_error[0:len(lamp_error):10]

#plt.figure(2)
plt.rc('font', size=12)
plt.rc('axes',linewidth=.5)
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.major.size'] = 2
plt.rcParams['ytick.major.size'] = 2
plt.rcParams['axes.linewidth'] = 2

fs_axon = 1.0/2000.0
t= np.linspace(0,len(lamp_means)/(1/fs_axon),len(lamp_means))

fig = plt.figure(figsize=(4,8))
fig.set_facecolor('w')

ax = fig.add_subplot(211)
ax.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
#ax.plot(t[1::20],lamp_means[1::20], 'k')
ax.plot(t[1::20],y[1::20], 'k')
ax.fill_between(t[1::20],lamp_means[1::20]+lamp_error[1::20], lamp_means[1::20]-lamp_error[1::20],color='k', alpha = 0.3, edgecolor = 'none')


ax.set_ylabel('WBA (rel. units)')
ax.spines['left'].set_bounds(0, .2)
#ax.set_ylim((-.75, .75))
ax.set_ylim((470, 510))
ax.set_xlim((0.5, 3.0))
#ax.set_yticks([0, .2])
#ax.set_xticks([])
ax.tick_params(axis='both', which='major', pad=2)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
'''


'''
('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t16/wbf_means.csv')
f17 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t17/wbf_means.csv')
f18 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t18/wbf_means.csv')
f19 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t19/wbf_means.csv')
f20 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t20/wbf_means.csv')
'''

#[f1['0'], f2['0'],f3['0'], f4['0'], f5['0'], f6['0'],
#all_wbf = [ f0['0'], f1['0'], f2['0'],f3['0'], f4['0'], f5['0'], f6['0'], f7['0'], 
##            f8['0'], f9['0'],
 #           f10['0'], f12['0'],f13['0'], f14['0'], f15['0'], f16['0'], f17['0'], 
 #           f18['0'], f19['0'],
 ##           f20['0'], f21['0'], f22['0'],f23['0'], f24['0'], f25['0'], f26['0'], f27['0'], 
  #          f28['0'], f29['0'], 
  #          f30['0'], f31['0'], f32['0'],f33['0'], f34['0'], f35['0'], f36['0'], f37['0'], 
  #          f38['0'], f39['0'], 
  #          f40['0'], f41['0'], f42['0'],f43['0'], f44['0'], f45['0'], f46['0'], f47['0'], 
  #          f48['0'], f49['0']]
            #f50['0'], f51['0'], f52['0'], f53['0'], f54['0'], f55['0'], f56['0'], f57['0'], 
            #f58['0'], f59['0'],
            #f60['0'], f61['0'], f62['0'],f63['0'], f64['0'], f65['0'], f66['0'], f67['0'], 
            #f68['0'], f69['0'],
            #f70['0'], f71['0'], f72['0'], f73['0'], f74['0'], f75['0'], f76['0'], f77['0'], 
            #f78['0'], f79['0'],
            #f80['0'], f81['0'], f82['0'],f83['0'], f84['0'], f85['0'], f86['0'], f87['0'], 
            #f88['0'], f89['0']]

#plt.figure(2)
plt.rc('font', size=12)
plt.rc('axes',linewidth=.5)
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.major.size'] = 2
plt.rcParams['ytick.major.size'] = 2
plt.rcParams['axes.linewidth'] = 2

wbf_means = np.mean(f_flight_values,axis = 1)
wbf_means = wbf_means[0:len(wbf_means):10]
wbf_error = stats.sem(f_flight_values,axis = 1)
wbf_error = wbf_error[0:len(wbf_error):10]

fig = plt.figure(figsize=(4,8))
fig.set_facecolor('w')


ax2 = fig.add_subplot(212)

#ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.plot(t,wbf_means, 'k', linewidth=0.4)
ax2.fill_between(t,wbf_means+wbf_error, wbf_means-wbf_error,color='k', alpha = 0.2, edgecolor = 'none')

ax2.set_ylabel(r'$\Delta$''WSA')
#ax2.spines['left'].set_bounds(180, 190)
#ax2.spines['bottom'].set_bounds(0.25, .75)
#ax2.set_xlim((0.5, 3.0))
#ax2.set_yticks([180, 190])
#ax2.set_xticks([.25, .75])
#ax2.tick_params(axis='both', which='major', pad=2)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
#ax2.spines['bottom'].set_visible(False)

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

#plt.savefig('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/' + 'WBA_WBF_summ.pdf', format = 'pdf', dpi = 300)
'''
#%%
plt.figure(2)
plt.plot(lamp_means, wbf_means, 'r.')
#plt.fill_between(lamp_means,wbf_means+wbf_error, wbf_means-wbf_error,color='k', alpha = 0.3, edgecolor = 'none')
#plt.fill_betweenx(wbf_means, lamp_means+lamp_error, lamp_means-lamp_error,color='k', alpha = 0.3, edgecolor = 'none')
'''

#fname = 'fly%s-%s-%s-summary.svg'%('summary',signal[0],signal[1])
fname = 'summary_signals_WBF_WSA_S248.pdf'
figure.savefig(fname, format='svg')
figure.savefig(fname, format='pdf')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-50-d1958cc4c702> in <module>()
#     152 #fname = 'fly%s-%s-%s-summary.svg'%('summary',signal[0],signal[1])
#     153 fname = 'summary_signals_WBF_WSA_S248.pdf'
# --> 154 figure.savefig(fname, format='svg')
#     155 figure.savefig(fname, format='pdf')
#
# NameError: name 'figure' is not defined

# %%
len(wbf_means)
# Out:
# 6000

# %%
for i in f_flight_values:

    fig = plt.figure(figsize=(4,8))
    fig.set_facecolor('w')



    ax2 = fig.add_subplot(212)

    #ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
    ax2.axvspan(1.0, 2.0, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
    ax2.plot(t,f_flight_values[i][::10], 'k')

    ax2.set_ylabel(r'$\Delta$''WBF (hz) ')
    #ax2.set_ylim(100, 450)
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    #ax2.spines['bottom'].set_visible(False)

    ax2.xaxis.set_ticks_position('bottom')
    ax2.yaxis.set_ticks_position('left')

    plt.show()

# %%
import numpy as np
from scipy.signal import butter, lfilter, freqz
import matplotlib.pyplot as plt


def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=0.2):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y


def butter_lowpass_filter_2(data, cutoff, fs, order=4):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

# Filter requirements.
order = 5
fs = 200.0       # sample rate, Hz
cutoff = 6.667  # desired cutoff frequency of the filter, Hz

# Get the filter coefficients so we can check its frequency response.
b, a = butter_lowpass(cutoff, fs, order)


y = butter_lowpass_filter(lamp_means, cutoff, fs, order)


y = butter_lowpass_filter(lamp_means, cutoff, fs, order)
error= butter_lowpass_filter(lamp_error, cutoff, fs, order)

fig = plt.figure(figsize=(8,4))
fig.set_facecolor('w')

ax = fig.add_subplot(212)
#plt.subplot(2, 1, 2)
ax.plot(t, lamp_means, 'b-', label='data')
ax.plot(t, y, 'g-', linewidth=2, label='filtered data')
#ax.xlabel('Time [sec]')
plt.grid()
plt.legend()
ax.set_ylim(475, 525)

plt.subplots_adjust(hspace=0.35)

# %%
import matplotlib
#import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
## JB's favorite Seaborn settings for notebooks
#rc={'lines.linewidth': 2, 'axes.labelsize': 18, 'axes.titlesize': 18}
#sns.set(rc=rc)









#f0 = pd.read_csv('/home/alysha/analysis_files/S114/csv/hist_crimson_spikes_s114_b1_01.csv')
#f1 = pd.read_csv('/home/alysha/analysis_files/S114/csv/hist_crimson_spikes_s104_b1_02.csv')
f2 = pd.read_csv('/home/alysha/analysis_files/S114/csv/hist_crimson_spikes_s114_b1_03.csv')
#f3 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_crimson_spikes_s104_b1_04.csv')
#f4 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_crimson_spikes_s104_b1_05.csv')
#f5 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_crimson_spikes_s104_b1_06.csv')
#f6 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_crimson_spikes_s104_b1_01.csv')

#f7 = pd.read_csv('/home/alysha/analysis_files/S114/csv/hist_no_crimson_spikes_s114_b1_01.csv')
#f8 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_no_crimson_spikes_s104_b1_02.csv')
f9 = pd.read_csv('/home/alysha/analysis_files/S114/csv/hist_no_crimson_spikes_s114_b1_03.csv')
#f10 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_no_crimson_spikes_s104_b1_04.csv')
#f11 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_no_crimson_spikes_s104_b1_05.csv')
#f12 = pd.read_csv('/home/alysha/analysis_files/S104/csv/hist_no_crimson_spikes_s104_b1_06.csv')

crim_on = [f2['0']]#,f6['0']]
crim_off = [ f9['0']]

result = pd.concat(crim_on)
neg_result= pd.concat(crim_off)

plt.xlabel('Rad')
plt.ylabel('Freq')
plt.title(r'$\mathrm{Histogram\ of\ b1 Activation}$')

#matplotlib.pyplot.hist(f2['0'], bins=100, normed=1, facecolor='yellow', alpha=0.75)
#matplotlib.pyplot.hist(f7['0'], bins=100, normed=1, facecolor='red', alpha=0.55)

matplotlib.pyplot.hist(neg_result, bins=60, normed=1, facecolor='blue', alpha=0.55)
matplotlib.pyplot.hist(result, bins=60, normed=1, facecolor='red', alpha=0.75)


plt.grid(False)

#plt.show()

fname = 'hist_1_b1_S110'

plt.savefig(fname, format='pdf')

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns

figure= plt.figure()

density = stats.gaussian_kde(neg_result)
n, x, _ = plt.hist(neg_result, bins=np.linspace(-3, 3, 60), 
                   histtype=u'step', normed=True,  alpha =1.0, lw=2, color = 'b')  
#plt.plot(x, density(x), color = 'b')
#plt.fill_between(x, density(x), alpha =0.2, color = 'b')

# bins=np.linspace(-3, 3, 50)
density_1 = stats.gaussian_kde(result)
n_1, x_1, _1 = plt.hist(result, bins=np.linspace(-3, 3, 60), 
                   histtype=u'step', normed=True, alpha = 1.0, lw=2, color = 'r')  
#plt.plot(x_1, density_1(x_1), color = 'r')
#plt.fill_between(x_1, density_1(x_1), alpha =0.2, color = 'r')


plt.show()

fname = 'hist_2_b1_S248.pdf'
#plt.savefig(fname, format='svg')
figure.savefig(fname)#, format='pdf')

# %%
#%%
f1 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t1/wbf_means.csv')
f2 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t2/wbf_means.csv')
f3 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t3/wbf_means.csv')
f4 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t4/wbf_means.csv')
f5 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t5/wbf_means.csv')
f6 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t6/wbf_means.csv')
f7 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t7/wbf_means.csv')

f8 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t8/wbf_means.csv')
f9 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t9/wbf_means.csv')
f10 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t10/wbf_means.csv')
f11 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t11/wbf_means.csv')
f12 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t12/wbf_means.csv')
f13 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t13/wbf_means.csv')
f14 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t14/wbf_means.csv')
f15 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t15/wbf_means.csv')
#
f16 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t16/wbf_means.csv')
f17 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t17/wbf_means.csv')
f18 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t18/wbf_means.csv')
f19 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t19/wbf_means.csv')
f20 = pd.read_csv('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/t20/wbf_means.csv')

all_wbf = [f1['0'], f2['0'],f3['0'], f4['0'], f5['0'], f6['0'], f7['0'], 
            f8['0'], f9['0']], f10['0'], f11['0'], f12['0'], f13['0'], 
            f14['0'], f15['0'], f16['0'], f17['0'], f18['0'], f19['0'], f20['0']]

wbf_means = np.mean(all_wbf,axis = 0)
wbf_means = wbf_means[0:len(wbf_means):10]
wbf_error = stats.sem(all_wbf,axis = 0)
wbf_error = wbf_error[0:len(wbf_error):10]

ax2 = fig.add_subplot(212)

ax2.axvspan(0.25, .75, facecolor = 'r', edgecolor = 'none', alpha = 0.3)
ax2.plot(t,wbf_means, 'k')
ax2.fill_between(t,wbf_means+wbf_error, wbf_means-wbf_error,color='k', alpha = 0.3, edgecolor = 'none')

ax2.set_ylabel(r'$\Delta$''WBF (Hz)')
ax2.spines['left'].set_bounds(180, 190)
ax2.spines['bottom'].set_bounds(0.25, .75)
ax2.set_ylim((165, 210))
ax2.set_xlim((-0.1, 1.2))
ax2.set_yticks([180, 190])
ax2.set_xticks([.25, .75])
ax2.tick_params(axis='both', which='major', pad=2)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
#ax2.spines['bottom'].set_visible(False)

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

#plt.savefig('/Volumes/hm_data/MN optogenetic activation/b1 proper hutchens/' + 'WBA_WBF_summ.pdf', format = 'pdf', dpi = 300)

#%%
plt.figure(2)
plt.plot(lamp_means, wbf_means, 'r.')
#plt.fill_between(lamp_means,wbf_means+wbf_error, wbf_means-wbf_error,color='k', alpha = 0.3, edgecolor = 'none')
#plt.fill_betweenx(wbf_means, lamp_means+lamp_error, lamp_means-lamp_error,color='k', alpha = 0.3, edgecolor = 'none')
